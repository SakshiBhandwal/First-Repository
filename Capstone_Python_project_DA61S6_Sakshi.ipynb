# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Task 1

# %%
df = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df  

# Reading the dataset.
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
import json

# %%
data = df.copy()

# %%
# storing the json format columns in a list

dict_columns = ['genres','keywords','production_companies','production_countries','spoken_languages']

# %%
for column in dict_columns:
    data[column] = data[column].apply(lambda x:[item['name'] for item in json.loads(x)])
    
# the lambda funcrion takes input as x and the json.loads(x) converts the json string into python dictionary
# the list comprehension extracts the value associated with the kay name [item['name']] for item

# %%
data
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
list_columns = ['genres','keywords','production_companies','production_countries','spoken_languages']

# storing the list format columns in the above list.

# %%
for column in list_columns:
    data[column] = data[column].str[0]

# %%
data
# Out:
#          budget       genres  \
# 0     237000000       Action
# 1     300000000    Adventure
# 2     245000000       Action
# 3     250000000       Action
# 4     260000000       Action
# ...         ...          ...
# 4798     220000       Action
# 4799       9000       Comedy
# 4800          0       Comedy
# 4801          0          NaN
# 4802          0  Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# ...

# %%
# dealing with the null values.

data.isnull().sum()
# Out:
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies     351
# production_countries     174
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages          86
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Title and genres of first 50 columns is displayed

data[['title','genres']].head(50)
# Out:
#                                           title           genres
# 0                                        Avatar           Action
# 1      Pirates of the Caribbean: At World's End        Adventure
# 2                                       Spectre           Action
# 3                         The Dark Knight Rises           Action
# 4                                   John Carter           Action
# 5                                  Spider-Man 3          Fantasy
# 6                                       Tangled        Animation
# 7                       Avengers: Age of Ultron           Action
# 8        Harry Potter and the Half-Blood Prince        Adventure
# 9            Batman v Superman: Dawn of Justice           Action
# 10                             Superman Returns        Adventure
# 11                            Quantum of Solace        Adventure
# 12   Pirates of the Caribbean: Dead Man's Chest        Adventure
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Handling the Null Values for Data Processing.

# %%
# dropped the homepage column as it contains only URL of the movie which is not necessary for the analysis

data = data.drop(['homepage'],axis=1)

# %%
# calculating the mode for keywords column

keywords_mode = data['keywords'].mode()[0]
keywords_mode
# Out:
# 'based on novel'

# %%
# filling the null values of keywords with the mode value.

data['keywords'].fillna(keywords_mode,inplace=True)

# %%
# calculating the mode for genres column.

genres_mode = data['genres'].mode()[0]
genres_mode
# Out:
# 'Drama'

# %%
# filling the null values of genre with the mode value.

data['genres'].fillna(genres_mode,inplace=True)

# %%
# calculating the mode for Production company column.

Production_company_mode = data['production_companies'].mode()[0]
Production_company_mode
# Out:
# 'Paramount Pictures'

# %%
# filling the null values of production_companies with the mode value.

data['production_companies'].fillna(Production_company_mode,inplace=True)

# %%
# calculating the mode for Production countries column.

production_countries_mode = data['production_countries'].mode()[0]
production_countries_mode
# Out:
# 'United States of America'

# %%
data['production_countries'].fillna(production_countries_mode,inplace=True)

# %%
# calculating the mode for runtime column.

runtime_mode = data['runtime'].mode()[0]
runtime_mode
# Out:
# 90.0

# %%
# filling the null values of runtime column with the mode value.

data['runtime'].fillna(runtime_mode,inplace=True)

# %%
release_date_mode = data['release_date'].mode()[0]
release_date_mode
# Out:
# '01-01-2006'

# %%
data['release_date'].fillna(release_date_mode,inplace=True)

# %%
spoken_languages_mode = data['spoken_languages'].mode()[0]
spoken_languages_mode
# Out:
# 'English'

# %%
data['spoken_languages'].fillna(spoken_languages_mode,inplace=True)

# %%
# overview and tagline can't be edited as mode or any assumption value therefore dropping their null values.

data = data.dropna()

# %%
data.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Task 3

# %%
# Here are the movie categories that have a budget greater than $220,000

data[data['budget'] >= 220000 ]
# Out:
#          budget     genres      id                      keywords  \
# 0     237000000     Action   19995                 culture clash
# 1     300000000  Adventure     285                         ocean
# 2     245000000     Action  206647                           spy
# 3     250000000     Action   49026                     dc comics
# 4     260000000     Action   49529                based on novel
# ...         ...        ...     ...                           ...
# 4666     225000    Foreign  139948                      michigan
# 4670     400000  Adventure    9659                         chain
# 4720    8500000      Drama  339408                       slavery
# 4758    4000000   Thriller  242095                        hacker
# 4798     220000     Action    9367  united states–mexico barrier
#
#      original_language                            original_title  \
# 0                   en                                    Avatar
# ...

# %% [markdown]
# #  Task 4

# %%
# Movie categories where the revenue is greater than $961,000,000

data[data['revenue'] >= 961000000 ]
# Out:
#         budget           genres      id        keywords original_language  \
# 0    237000000           Action   19995   culture clash                en
# 1    300000000        Adventure     285           ocean                en
# 3    250000000           Action   49026       dc comics                en
# 7    280000000           Action   99861    marvel comic                en
# 12   200000000        Adventure      58           witch                en
# 16   220000000  Science Fiction   24428        new york                en
# 17   380000000        Adventure    1865             sea                en
# 25   200000000            Drama     597       shipwreck                en
# 26   250000000        Adventure  271110       civil war                en
# 28   150000000           Action  135397         monster                en
# 29   200000000           Action   37724             spy                en
# 31   200000000           Action   68721       terrorist                en
# ...

# %% [markdown]
# # Task 5

# %%
# removing the budget and revenue columns with value zero.

data = data[(data['revenue'] != 0) & (data['budget'] != 0)]
data
# Out:
#          budget           genres      id                      keywords  \
# 0     237000000           Action   19995                 culture clash
# 1     300000000        Adventure     285                         ocean
# 2     245000000           Action  206647                           spy
# 3     250000000           Action   49026                     dc comics
# 4     260000000           Action   49529                based on novel
# ...         ...              ...     ...                           ...
# 4773      27000           Comedy    2292                    salesclerk
# 4788      12000           Horror     692                           gay
# 4792      20000            Crime   36095                         japan
# 4796       7000  Science Fiction   14337                      distrust
# 4798     220000           Action    9367  united states–mexico barrier
#
#      original_language                            original_title  \
# ...

# %% [markdown]
# # Task 6

# %%
# Top 10 movies with highest revenue

data.sort_values(by='revenue',ascending=False).head(20)[['original_title','genres','revenue']]
# Out:
#                                     original_title           genres  \
# 0                                           Avatar           Action
# 25                                         Titanic            Drama
# 16                                    The Avengers  Science Fiction
# 28                                  Jurassic World           Action
# 44                                       Furious 7           Action
# 7                          Avengers: Age of Ultron           Action
# 124                                         Frozen        Animation
# 31                                      Iron Man 3           Action
# 546                                        Minions           Family
# 26                      Captain America: Civil War        Adventure
# 52                  Transformers: Dark of the Moon           Action
# 329  The Lord of the Rings: The Return of the King        Adventure
# 29                                         Skyfall           Action
# ...

# %%
max(data['revenue'])
# Out:
# 2787965087

# %%
min(data['revenue'])
# Out:
# 5

# %%
round((data['revenue']).mean())
# Out:
# 127508414

# %%
# Top 10 movies with least budget.

Low_budget=data.sort_values(by='budget',ascending= True).head(10)
Low_budget[['original_title','budget']]
# Out:
#                    original_title  budget
# 4238                 Modern Times       1
# 3611           A Farewell to Arms       4
# 3419                 Bran Nue Dae       7
# 3372                 Split Second       7
# 4608                 The Prophecy       8
# 3137                    Nurse 3-D      10
# 1771               The 51st State      28
# 1562  Rugrats in Paris: The Movie      30
# 4796                       Primer    7000
# 4696                      Weekend    8000

# %%
# Top 10 movies with least popularity.
Low_popular=data.sort_values(by='popularity',ascending= True).head(10)
Low_popular[['original_title','popularity','genres']]
# Out:
#                                        original_title  popularity       genres
# 4105  The Book of Mormon Movie, Volume 1: The Journey    0.031947        Drama
# 3225                                            Limbo    0.034259    Adventure
# 4371                                             Fiza    0.043023        Drama
# 3419                                     Bran Nue Dae    0.050456       Comedy
# 2303                                   The Nutcracker    0.068228       Family
# 4306                               Pink Ribbons, Inc.    0.097913  Documentary
# 4524        Sholem Aleichem: Laughing In The Darkness    0.109579  Documentary
# 4666                                             Burn    0.126676      Foreign
# 4701                Sweet Sweetback's Baadasssss Song    0.132878       Action
# 1039                                           Inchon    0.146783        Drama

# %% [markdown]
# # Task 7

# %%
# calculating the correlation between budget and popularity

correlation = data['budget'].corr(data['popularity'])
correlation.round(2)

# correlation is positive, hence there is a positive relationship between the budget and popularity.
# Out:
# 0.42

# %%
# calculating the correlation between budget and revenue
corr = data['budget'].corr(data['revenue'])
corr.round(2)

# correlation is near to zero hence, there's no systematic relatioship between revenue & budget.
# Out:
# 0.7

# %%
# correlation between  revenue and popularity.
cor = data['popularity'].corr(data['revenue'])
cor.round(2)
# There is a positive relationship between the revenue and popularity.
# Out:
# 0.59

# %%
print('Budget & Popularity ',correlation.round(2))
print('Budget & Revenue    ',corr.round(2))
print('Popularity & Revenue',cor.round(2))
# Out:
# Budget & Popularity  0.42
# Budget & Revenue     0.7
# Popularity & Revenue 0.59

# %%
plt.xlabel('Budget')
plt.ylabel('Popularity')
sb.scatterplot(x='budget',y='popularity',data=data)
plt.show()

# %% [markdown]
# # Task 8

# %%
# Displaying production companies along with the number of times they've appeared in the dataset.
data.groupby(by=['production_companies'])['production_companies'].count()
# Out:
# production_companies
# 100 Bares                  1
# 1492 Pictures              4
# 1818                       1
# 19 Entertainment           1
# 21 Laps Entertainment      1
#                           ..
# Yeah                       1
# Younggu-Art Movies         1
# Zentropa Entertainments    3
# Zininsa Film Production    1
# icon                       1
# Name: production_companies, Length: 678, dtype: int64

# %% [markdown]
# # Task 9

# %%
# Here are the Top 25 companies based on the number of movies they've produced

data.groupby(by=['production_companies'])['title'].count().sort_values(ascending = False).head(25)
# Out:
# production_companies
# Paramount Pictures                        248
# Universal Pictures                        223
# Columbia Pictures                         161
# Twentieth Century Fox Film Corporation    151
# New Line Cinema                           130
# Walt Disney Pictures                       90
# Village Roadshow Pictures                  63
# Miramax Films                              55
# United Artists                             54
# DreamWorks SKG                             54
# Columbia Pictures Corporation              52
# Warner Bros.                               49
# Fox Searchlight Pictures                   41
# Summit Entertainment                       40
# TriStar Pictures                           36
# Metro-Goldwyn-Mayer (MGM)                  29
# The Weinstein Company                      26
# Lionsgate                                  26
# Regency Enterprises                        25
# Imagine Entertainment                      24
# ...

# %% [markdown]
# # Task 10

# %%
# Filtering the Top 500 movies based on the revenue

Top_500_Movies = data.sort_values(by='revenue',ascending=False).head(500)
Top_500_Movies
# Out:
#          budget           genres      id       keywords original_language  \
# 0     237000000           Action   19995  culture clash                en
# 25    200000000            Drama     597      shipwreck                en
# 16    220000000  Science Fiction   24428       new york                en
# 28    150000000           Action  135397        monster                en
# 44    190000000           Action  168259       car race                en
# ...         ...              ...     ...            ...               ...
# 2279   20000000           Comedy   52449      classroom                en
# 677    62000000           Action    9331  assassination                en
# 1167   40000000          Romance    6114       adultery                en
# 523    75000000           Action   11678       himalaya                en
# 589    70000000           Horror   49017        vampire                en
#
#                 original_title  \
# 0                       Avatar
# ...

# %% [markdown]
# # Measure of Central Tendency
# ## Budget

# %%
# calculating the Mean of budget

data['budget'].mean()
# Out:
# 42167447.613270774

# %%
# calculating the median of budget.
data['budget'].median()
# Out:
# 27000000.0

# %%
# calculating the mode of budget.

data['budget'].mode()[0]
# Out:
# 20000000

# %%
# outliers for budget

data['budget'].plot(kind='box',vert=0,showmeans = True)
plt.show()

# %% [markdown]
# ## Runtime

# %%
# calculating the Mean of Runtime.

data['runtime'].mean()
# Out:
# 110.74028150134048

# %%
# calculating the median of Runtime.

data['runtime'].median()
# Out:
# 107.0

# %%
# calculating the mode of runtime.

data['runtime'].mode()[0]
# Out:
# 100.0

# %%
# Outliers for runtime

data['runtime'].plot(kind='box',vert=0,showmeans = True)
plt.show()

# %% [markdown]
# ## Revenue

# %%
# calculating the Mean of revenue

data['revenue'].mean()
# Out:
# 127508414.07908848

# %%
# calculating the median of Revenuw.

data['revenue'].median()
# Out:
# 60827798.0

# %%
# calculating the mode of Revenue

data['revenue'].mode()[0]
# Out:
# 6000000

# %%
# outliers for revenue

data['revenue'].plot(kind='box',vert=0,showmeans = True)
plt.show()

# %%
# Out:
# 0.7

# %% [markdown]
# # Task 11

# %%
# Here are the movies whose runtime is greater than the average runtime.

above_avg_movies = data[data['runtime'] > data['runtime'].mean()]
above_avg_movies[['original_title','runtime']]
# Out:
#                                 original_title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4606                       Tupac: Resurrection    112.0
# 4631                               Chasing Amy    113.0
# 4720                     The Birth of a Nation    120.0
# 4722                         Facing the Giants    111.0
# 4792                                       キュア    111.0
#
# [1259 rows x 2 columns]
